# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (3.13.3)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Using cached langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (1.6.3)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (0.4.20)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.2.6)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.11.7)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.17.1)
# Requirement already satisfied: anyio in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (4.10.0)
# Requirement already satisfied: certifi in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sneha pandey\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (1.3.1)
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
# Installing collected packages: httpx-sse, pydantic-settings, langchain-text-splitters, langchain-classic, langchain-community
#
#    -------- ------------------------------- 1/5 [pydantic-settings]
#    -------- ------------------------------- 1/5 [pydantic-settings]
#    -------- ------------------------------- 1/5 [pydantic-settings]
#    -------- ------------------------------- 1/5 [pydantic-settings]
#   Attempting uninstall: langchain-text-splitters
#    -------- ------------------------------- 1/5 [pydantic-settings]
#     Found existing installation: langchain-text-splitters 0.3.10
#    -------- ------------------------------- 1/5 [pydantic-settings]
#     Uninstalling langchain-text-splitters-0.3.10:
#    -------- ------------------------------- 1/5 [pydantic-settings]
#       Successfully uninstalled langchain-text-splitters-0.3.10
#    -------- ------------------------------- 1/5 [pydantic-settings]
#    ---------------- ----------------------- 2/5 [langchain-text-splitters]
#    ---------------- ----------------------- 2/5 [langchain-text-splitters]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    ------------------------ --------------- 3/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    ---------------------------------------- 5/5 [langchain-community]
#
# Successfully installed httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-text-splitters-1.1.2 pydantic-settings-2.15.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~angchain-core (c:\Users\Sneha Pandey\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-core (c:\Users\Sneha Pandey\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-core (c:\Users\Sneha Pandey\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver
# Out:
# C:\Users\Sneha Pandey\AppData\Local\Temp\ipykernel_26148\3293250410.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import GoogleSerperAPIWrapper

# %%
llm = ChatGroq(model="openai/gpt-oss-120b")
search=GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="You are a helpful assistant that can answer questions using Google search results.",
    checkpointer=MemorySaver()
)

# %%
question = "by how many goals?"

# %%
response=agent.invoke(
    {"messages": [{"role": "user", "content": question}]},
    {"configurable":{"thread_id":"asd123"}})

# %%
response["messages"][-1].content
# Out:
# 'The final ended\u202f3‑3 after extra time, and Argentina clinched the title by winning the penalty shoot‑out **4‑2**.  \nSo the victory margin was **two goals** in the shoot‑out.'
