# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-120b", streaming=True)

# %%
question="what is genai answer in detail?"

# %%
response=llm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# ## Generative AI (GenAI) Answer – A Detailed Walk‑through
#
# Below is a comprehensive explanation of what a **GenAI answer** is, how it is produced, the technology that powers it, the steps that happen behind the scenes, its strengths and limits, and how you can work with it effectively.
#
# ---
#
# ## 1.  What Do We Mean by “GenAI Answer”?
#
# A **GenAI answer** is a piece of text (or other media) that is generated **on‑the‑fly** by a **generative artificial‑intelligence system** in response to a user’s prompt or query.
#
# | Aspect | Traditional (static) answer | GenAI answer |
# |--------|-----------------------------|--------------|
# | **Source** | Hand‑written, curated, or retrieved from a fixed knowledge base | Produced by a model that *creates* language (or images, code, etc.) in real time |
# | **Flexibility** | Fixed wording, limited to pre‑written content | Can adapt style, length, format, and incorporate novel combinations of concepts |
# ...
