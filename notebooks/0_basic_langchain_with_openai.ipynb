# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
res = llm.invoke("Who is the PM of India?")
print(res.content)
# Out:
# As of September 2026, the Prime Minister of India is **Narendra Modi**. He has been in office since May 2014, having been re‑elected in the 2019 and 2024 general elections.

# %%
prompts=[
    ("system","You are a python developer"),
    ("user","how to sort an array")
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# Below is a quick‑reference guide to sorting an array (list) in Python, followed by several common variations you might need.
#
# ---
#
# ## 1. The basics
#
# ```python
# # Unsorted list
# numbers = [5, 2, 9, 1, 7]
#
# # 1️⃣ In‑place sort (modifies the original list)
# numbers.sort()
# print(numbers)          # → [1, 2, 5, 7, 9]
#
# # 2️⃣ Return a new sorted list (original stays unchanged)
# sorted_numbers = sorted([5, 2, 9, 1, 7])
# print(sorted_numbers)   # → [1, 2, 5, 7, 9]
# print([5, 2, 9, 1, 7])  # original unchanged
# ```
#
# * `list.sort()` **mutates** the list and returns `None`.
# * `sorted(iterable)` works on any iterable (list, tuple, generator, etc.) and **returns a new list**.
#
# Both use **Timsort**, a hybrid stable sorting algorithm (O(n log n) worst‑case, O(n) best‑case for already‑sorted data).
#
# ---
#
# ## 2. Sorting in reverse (descending) order
#
# ```python
# numbers = [5, 2, 9, 1, 7]
#
# # In‑place
# numbers.sort(reverse=True)
# print(numbers)          # → [9, 7, 5, 2, 1]
#
# # New list
# sorted_desc = sorted(numbers, reverse=True)
# print(sorted_desc)      # → [9, 7, 5, 2, 1]
# ```
#
# ---
#
# ## 3. Sorting by a custom key
#
# Often you want to sort on something other than the element itself.
#
# ### a) Sort strings by length
#
# ```python
# words = ["apple", "banana", "kiwi", "cherry"]
# words.sort(key=len)                 # → ['kiwi', 'apple', 'cherry', 'banana']
# ```
#
# ### b) Sort tuples/dictionaries by a specific field
#
# ```python
# people = [
#     {"name": "Alice", "age": 30},
#     {"name": "Bob",   "age": 25},
#     {"name": "Cara",  "age": 35},
# ]
#
# # Sort by age (ascending)
# people.sort(key=lambda p: p["age"])
# # → [{'name': 'Bob', 'age': 25}, {'name': 'Alice', 'age': 30}, {'name': 'Cara', 'age': 35}]
# ```
#
# ### c) Sort by multiple criteria
#
# ```python
# # First by age, then by name alphabetically
# people.sort(key=lambda p: (p["age"], p["name"]))
# ```
#
# ### d) Sort objects by an attribute
#
# ```python
# class Point:
#     def __init__(self, x, y):
#         self.x, self.y = x, y
#
# pts = [Point(2, 3), Point(1, 5), Point(2, 1)]
#
# # Sort by x, then by y
# pts.sort(key=lambda p: (p.x, p.y))
# ```
#
# ---
#
# ## 4. Stable vs. unstable sorting
#
# Python’s sort is **stable**: equal‑key elements retain their original relative order.
#
# ```python
# data = [('a', 2), ('b', 1), ('c', 2)]
#
# # First sort by the second element
# data.sort(key=lambda t: t[1])
# # → [('b', 1), ('a', 2), ('c', 2)]
#
# # If we now sort by the first element, the previous order of the 2‑values is kept
# data.sort(key=lambda t: t[0])
# # → [('a', 2), ('b', 1), ('c', 2)]
# ```
#
# ---
#
# ## 5. Sorting non‑comparable items (e.g., `None` mixed with numbers)
#
# Python 3 will raise a `TypeError` if you try to compare incomparable types. Use a key that normalizes them:
#
# ```python
# mixed = [3, None, 1, None, 2]
#
# def safe_key(x):
#     # Treat None as larger than any number
#     return (x is None, x if x is not None else 0)
#
# mixed.sort(key=safe_key)   # → [1, 2, 3, None, None]
# ```
#
# ---
#
# ## 6. Sorting large data sets efficiently
#
# * **In‑place** (`list.sort`) saves memory because it doesn’t create a copy.
# * If you need a **stable** order *and* want to avoid the extra memory of `sorted`, use `list.sort`.
# * For **external sorting** (data that doesn’t fit in RAM), consider the `heapq.merge` function with sorted chunks written to temporary files, or use a library like **pandas** / **dask** for out‑of‑core sorting.
#
# ---
#
# ## 7. Quick cheat‑sheet
#
# | Operation | Syntax | Returns | Mutates original? |
# |-----------|--------|---------|-------------------|
# | Ascending, in‑place | `mylist.sort()` | `None` | **Yes** |
# | Descending, in‑place | `mylist.sort(reverse=True)` | `None` | **Yes** |
# | Ascending, new list | `sorted(mylist)` | `list` | No |
# | Descending, new list | `sorted(mylist, reverse=True)` | `list` | No |
# | Custom key | `mylist.sort(key=func)` or `sorted(mylist, key=func)` | — | — |
# | Multiple keys | `key=lambda x: (x.first, x.second)` | — | — |
#
# ---
#
# ## 8. Full example – putting it all together
#
# ```python
# # Sample data: list of dictionaries representing books
# books = [
#     {"title": "Python Crash Course", "year": 2015, "pages": 544},
#     {"title": "Automate the Boring Stuff", "year": 2015, "pages": 504},
#     {"title": "Fluent Python", "year": 2015, "pages": 792},
#     {"title": "Effective Python", "year": 2015, "pages": 256},
#     {"title": "Learning Python", "year": 2013, "pages": 1648},
# ]
#
# # 1️⃣ Sort by publication year (oldest → newest)
# books_by_year = sorted(books, key=lambda b: b["year"])
#
# # 2️⃣ Within the same year, sort by page count descending
# books_by_year_and_pages = sorted(
#     books,
#     key=lambda b: (b["year"], -b["pages"])
# )
#
# # 3️⃣ In‑place sort by title alphabetically (case‑insensitive)
# books.sort(key=lambda b: b["title"].lower())
#
# # Print results
# print("By year:")
# for b in books_by_year:
#     print(f'{b["year"]}: {b["title"]} ({b["pages"]}p)')
#
# print("\nBy year + pages (desc):")
# for b in books_by_year_and_pages:
#     print(f'{b["year"]}: {b["title"]} ({b["pages"]}p)')
#
# print("\nIn‑place by title:")
# for b in books:
#     print(b["title"])
# ```
#
# ---
#
# ### TL;DR
#
# * Use **`list.sort()`** for an in‑place, memory‑efficient sort.
# * Use **`sorted(iterable)`** when you need a new sorted list or are dealing with any iterable.
# * Pass **`reverse=True`** for descending order.
# * Pass a **`key=`** function (or lambda) to sort on custom criteria, multiple criteria, or to handle mixed‑type data.
#
# Feel free to ask if you have a specific data structure or sorting rule you’d like to see implemented!

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-3.8-flash"
)

# %%
res = llm.invoke("Who is the PM of India?")

print(res.content)
# Out:
# The Prime Minister of India is **Narendra Modi**. He has been serving in this position since May 2014.
