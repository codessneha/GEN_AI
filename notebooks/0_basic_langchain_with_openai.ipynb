# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
res = llm.invoke("Who is the PM of India?")
print(res.content)
# Out:
# As of September 2026, the Prime Minister of India is **Narendra Modi**. He has been in office since May 2014, winning re‑elections in 2019 and 2024.

# %%
prompts=[
    ("system","You are a python developer"),
    ("user","how to sort an array")
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# Below is a quick‑reference guide for sorting **arrays (lists)** in Python, covering the most common use‑cases and a few advanced tricks.
#
# ---
#
# ## 1. The built‑in ways
#
# | Function / method | Returns a new list? | In‑place? | Typical use |
# |-------------------|---------------------|-----------|-------------|
# | `sorted(iterable, *, key=None, reverse=False)` | ✅ | ❌ | When you want a **new sorted list** and keep the original untouched. |
# | `list.sort(key=None, reverse=False)` | ❌ | ✅ | When you want to **mutate** the existing list (fastest, no extra memory). |
#
# ### 1.1 Simple numeric list
#
# ```python
# nums = [5, 2, 9, 1, 7]
#
# # 1️⃣ New sorted list
# sorted_nums = sorted(nums)          # [1, 2, 5, 7, 9]
# print(sorted_nums)
#
# # 2️⃣ In‑place sort
# nums.sort()                         # nums becomes [1, 2, 5, 7, 9]
# print(nums)
# ```
#
# ### 1.2 Sorting strings (lexicographically)
#
# ```python
# words = ["banana", "Apple", "cherry", "date"]
# print(sorted(words))                # ['Apple', 'banana', 'cherry', 'date']
# ```
#
# If you want a case‑insensitive order:
#
# ```python
# print(sorted(words, key=str.lower)) # ['Apple', 'banana', 'cherry', 'date']
# ```
#
# ### 1.3 Descending order
#
# ```python
# print(sorted(nums, reverse=True))  # [9, 7, 5, 2, 1]
# # or
# nums.sort(reverse=True)            # mutates nums
# ```
#
# ---
#
# ## 2. Custom sorting criteria
#
# You can supply a **key function** that extracts the value to compare.
#
# ### 2.1 Sort by length of a string
#
# ```python
# words = ["pear", "apple", "banana", "fig"]
# print(sorted(words, key=len))       # ['fig', 'pear', 'apple', 'banana']
# ```
#
# ### 2.2 Sort a list of tuples by the second element
#
# ```python
# pairs = [(1, 'b'), (3, 'a'), (2, 'c')]
# print(sorted(pairs, key=lambda t: t[1]))
# # [(3, 'a'), (1, 'b'), (2, 'c')]
# ```
#
# ### 2.3 Sort objects by an attribute
#
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#     def __repr__(self):
#         return f"{self.name}:{self.age}"
#
# people = [Person('Alice', 30), Person('Bob', 25), Person('Cara', 35)]
#
# # Sort by age (ascending)
# people.sort(key=lambda p: p.age)
# print(people)   # [Bob:25, Alice:30, Cara:35]
# ```
#
# ---
#
# ## 3. Sorting **NumPy** arrays
#
# If you are working with numeric data in a `numpy.ndarray`, use `np.sort` (returns a new array) or the `sort` method (in‑place).
#
# ```python
# import numpy as np
#
# arr = np.array([5, 2, 9, 1, 7])
#
# # New sorted array
# sorted_arr = np.sort(arr)          # array([1, 2, 5, 7, 9])
# print(sorted_arr)
#
# # In‑place
# arr.sort()                         # arr becomes array([1, 2, 5, 7, 9])
# print(arr)
# ```
#
# For multi‑dimensional arrays you can specify the axis:
#
# ```python
# mat = np.array([[3, 1], [2, 4]])
# print(np.sort(mat, axis=0))   # sort each column
# print(np.sort(mat, axis=1))   # sort each row
# ```
#
# ---
#
# ## 4. Stability & performance notes
#
# * **Stability** – Python’s sort is *stable*: equal elements keep their original relative order. This matters when you sort twice on different keys (e.g., first by `last_name`, then by `first_name`).
# * **Complexity** – `list.sort()` and `sorted()` use **Timsort**, O(n log n) worst‑case, O(n) best‑case for already‑sorted data.
# * **Memory** – In‑place `list.sort()` needs only O(1) extra space (apart from the call stack). `sorted()` creates a new list, costing O(n) extra memory.
#
# ---
#
# ## 5. Quick cheat‑sheet
#
# ```python
# # 1️⃣ New list, ascending
# new = sorted(my_list)
#
# # 2️⃣ New list, descending
# new = sorted(my_list, reverse=True)
#
# # 3️⃣ New list, custom key
# new = sorted(my_list, key=my_key_func)
#
# # 4️⃣ In‑place, ascending
# my_list.sort()
#
# # 5️⃣ In‑place, descending
# my_list.sort(reverse=True)
#
# # 6️⃣ In‑place, custom key
# my_list.sort(key=my_key_func)
# ```
#
# ---
#
# ### TL;DR
#
# * Use **`sorted()`** when you need a fresh sorted copy.
# * Use **`list.sort()`** when you can modify the original list (fastest, no extra memory).
# * Supply a **`key=`** function for any custom ordering, and **`reverse=True`** for descending order.
# * For numeric heavy lifting, switch to **NumPy** and its `np.sort`/`.sort()`.
#
# Feel free to ask if you have a specific data structure or sorting rule in mind!

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-3.8-flash"
)

# %%
res = llm.invoke("Who is the PM of India?")

print(res.content)
# Out:
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised RetryError: Timeout of 600.0s exceeded, last exception: 503 Stream removed (WSAGetOverlappedResult: Connection aborted (An established connection was aborted by the software in your host machine.
#  -- 10053)).
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 4.0 seconds as it raised RetryError: Timeout of 600.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNAVAILABLE: ipv4:172.217.115.4:443: WSAGetOverlappedResult: Network is unreachable (A socket operation was attempted to an unreachable network.
#  -- 10051).
# The Prime Minister of India is **Narendra Modi**.
